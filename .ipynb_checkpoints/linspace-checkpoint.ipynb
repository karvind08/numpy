# %%
from numpy import random

# %%
x = random.randint(1,5,size=(3,3))
print(x)
# Out:
# [[1 2 1]
#  [2 4 3]
#  [2 2 4]]

# %%
y = random.rand(3,3)
print(y)
# Out:
# [[0.52115965 0.13657501 0.58617366]
#  [0.26047314 0.97051541 0.69538283]
#  [0.27568131 0.18245956 0.38949093]]

# %%
a = random.randint(100,size=(3,4))
print(a)
# Out:
# [[48 25 72 80]
#  [39 32 71 18]
#  [60 47 82 72]]

# %%
b = random.rand(3,5)
print(b)
# Out:
# [[0.3863287  0.96126891 0.17018426 0.85606271 0.86517537]
#  [0.91496179 0.08702249 0.99931322 0.17687777 0.12906284]
#  [0.20890889 0.9613305  0.72078479 0.2729156  0.79665386]]

# %%
c = random.choice([3, 5, 7, 9])
print(c)
# Out:
# 3

# %%
d = random.choice([3, 5, 7, 9],size=5)
print(d)
# Out:
# [5 7 3 9 9]

# %%
numbers = [1,2,3,4,5]
random.shuffle(numbers)
print(numbers)
# Out:
# [2, 3, 5, 1, 4]

# %%
number1 = (1,2,3,4,5)
random.shuffle(number1)
print(number1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-70-fc586158f6c6> in <module>
#       1 number1 = (1,2,3,4,5)
# ----> 2 random.shuffle(number1,2)
#       3 print(number1)
#
# TypeError: shuffle() takes exactly one argument (2 given)

# %%
number1 = (1,22,3,4,5)
e= random.sample(number1)
print(e)
# Out:
# [[[[[0.73141637 0.09069784 0.62909864 0.11677832 0.95358126]
#     [0.18194732 0.6542075  0.59714127 0.67986696 0.12702397]
#     [0.23681071 0.94757628 0.83326601 0.20782427 0.68175495]
#     [0.55964203 0.71769594 0.86924494 0.63229593 0.74176288]]
#
#    [[0.47065668 0.15667531 0.00839299 0.3878676  0.57238167]
#     [0.51679379 0.80435297 0.02562274 0.47917843 0.86613185]
#     [0.85664443 0.86910643 0.34035141 0.99512834 0.84230557]
#     [0.22078699 0.88763562 0.9450287  0.97182148 0.75732804]]
#
#    [[0.49314123 0.69556773 0.89385651 0.88678553 0.82297631]
#     [0.364229   0.86128866 0.70642631 0.88162801 0.14307319]
#     [0.39775725 0.1622824  0.65322579 0.52478793 0.25189583]
#     [0.06212453 0.98838365 0.45449924 0.45836361 0.29563309]]]
#
#
#   [[[0.94082206 0.22218261 0.21420834 0.1028848  0.09604169]
#     [0.32372328 0.22639511 0.06054645 0.68268092 0.62262507]
#     [0.20102203 0.40466536 0.29301921 0.81427204 0.68041901]
# ...
